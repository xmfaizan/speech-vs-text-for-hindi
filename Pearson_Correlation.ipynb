# %%
import pandas as pd
df = pd.read_csv('my_dataframe.csv',encoding='utf-8')
df.head()
# Out:
#                                                texts  label  parse_tree_depth  \
# 0  अमेरिकी और रूसी पुलिस के संयुक्त अभियान के फलस...      0                 2
# 1  आज यहां रांची एक्सप्रेस के साथ बातचीत में वित्...      0                 2
# 2                                   हमे इन्तजार है ।      1                 1
# 3       जिस के नतीजे मे ये हुक्म सादिर किया गया है ।      1                 2
# 4                                              जयपुर      0                 0
#
#    noun_count_hi  verb_count_hi  adverb_count_hi  pronoun_count_hi  \
# 0              7              2                0                 0
# 1              2              1                0                 1
# 2              1              0                0                 1
# 3              3              1                0                 1
# 4              0              0                0                 0
#
#    total_words_hi  noun_percentage_hi  verb_percentage_hi  ...  \
# ...

# %%
X = df.drop('label', axis=1)
X = X.drop('texts', axis=1)
y = df['label']

# %%
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
logistic_regression = LogisticRegression(random_state=42)
logistic_regression.fit(X_train, y_train)
y_pred_logistic = logistic_regression.predict(X_test)
accuracy_logistic = accuracy_score(y_test, y_pred_logistic)
print("\nLogistic Regression Accuracy:", accuracy_logistic)
print("\nClassification Report:")
print(classification_report(y_test, y_pred_logistic))
# Out:
# Logistic Regression Accuracy: 0.8929956060997674
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89      3826
#            1       0.90      0.89      0.89      3912
#
#     accuracy                           0.89      7738
#    macro avg       0.89      0.89      0.89      7738
# weighted avg       0.89      0.89      0.89      7738

# %%
from scipy.stats import pearsonr
correlations = []
for column in X.columns:
    correlation, pvalue = pearsonr(X[column], y)
    correlations.append(correlation)

# %%
correlation_df = pd.DataFrame({
    "Feature": X.columns,
    "Pearson Correlation": correlations
})

# Sort the DataFrame by the Pearson correlation coefficient
correlation_df = correlation_df.sort_values(by="Pearson Correlation", ascending=False)

correlation_df.head(25)
# Out:
#                     Feature  Pearson Correlation
# 9     pronoun_percentage_hi             0.347494
# 17       hesitation_markers             0.297097
# 4          pronoun_count_hi             0.264712
# 18        wh_question_count             0.144860
# 3           adverb_count_hi             0.138223
# 8      adverb_percentage_hi             0.124449
# 2             verb_count_hi             0.088996
# 7        verb_percentage_hi             0.083690
# 0          parse_tree_depth             0.078161
# 15        conjunction_count             0.058989
# 10           words_per_sent             0.042046
# 5            total_words_hi             0.028290
# 16  conjunctions_percentage            -0.033822
# 1             noun_count_hi            -0.077183
# 14        case_marker_count            -0.144680
# 12         token_type_ratio            -0.189591
# 6        noun_percentage_hi            -0.342296
# 13         case_marker_perc            -0.472032
# ...

# %% [markdown]
# Spoken text characteristics:
#
# * Higher use of pronouns (both in percentage and count)
# * More hesitation markers
# * Slightly higher use of adverbs
# * More WH-questions
# * Slightly deeper parse trees
#
#
# Written text characteristics:
#
# * Longer words (higher average characters per word)
# * More case markers
# * Higher noun percentage
# * Higher token type ratio (more diverse vocabulary)
